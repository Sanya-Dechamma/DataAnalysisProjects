# %%
import pandas as pd

# %%
df = pd.read_csv('CricketTestMatchData.csv')

# %%
df
# Out:
#                    Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0        DG Bradman (AUS)  1928-1948   52    80  10   6996   334  99.94
# 1          HC Brook (ENG)  2022-2023   12    20   1   1181   186  62.15
# 2          AC voges (AUS)  2015-2016   20    31   7   1485  269*  61.87
# 3         RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 4         GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83
# ..                    ...        ...  ...   ...  ..    ...   ...    ...
# 59        SJ McCabe (AUS)  1930-1938   39    62   5   2748   232  48.21
# 60       DR Jardine (ENG)  1928-1934   22    33   6   1296   127  48.00
# 61         J  Ryder (AUS)  1920-1929   20    32   5   1394  201*  51.61
# 62         J  Ryder (AUS)  1920-1929   20    32   5   1394  201*  51.61
# 63  DPMD Jayawardene (SL)  1997-2014  149   252  15  11814   374  49.84
#
#       B F     SR  100  50   0     4s  6s
# 0   9800+  58.60   29  13   7   626+   6
# ...

# %%
df = df.rename(columns = {'Mat': 'Matches','NO':'Not_Out', 'HS':'Highest_inn_score', 'SR':'Strike_rate', 'Ave':'Avg', 'B F':'BallsFaced'})

# %%
df.head(5)
# Out:
#              Player       Span  Matches  Inns  Not_Out  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80       10  6996
# 1    HC Brook (ENG)  2022-2023       12    20        1  1181
# 2    AC voges (AUS)  2015-2016       20    31        7  1485
# 3   RG Pollock (SA)  1963-1970       23    41        4  2256
# 4   GA Headley (WI)  1930-1954       22    40        4  2190
#
#   Highest_inn_score    Avg BallsFaced  Strike_rate  100  50  0     4s  6s
# 0               334  99.94      9800+        58.60   29  13  7   626+   6
# 1               186  62.15       1287        91.76    4   7  1    141  23
# 2              269*  61.87       2667        55.68    5   4  2    186   5
# 3               274  60.97      1707+        54.48    7  11  1   246+  11
# 4              270*  60.83       416+        56.00   10   5  2  104 +   1

# %%
#check for null values and fix null values

# %%
df.isnull().any()
# Out:
# Player               False
# Span                 False
# Matches              False
# Inns                 False
# Not_Out              False
# Runs                 False
# Highest_inn_score    False
# Avg                  False
# BallsFaced            True
# Strike_rate          False
# 100                  False
# 50                   False
# 0                    False
# 4s                   False
# 6s                   False
# dtype: bool

# %%
df[df['BallsFaced'].isna()==1]
# Out:
#                   Player       Span  Matches  Inns  Not_Out  Runs  \
# 8         ED Weekes (WI)  1948-1958       48    81        5  4455
# 14       CL Walcott (WI)  1948-1960       44    74        7  3798
# 53  Hon.FS Jackson (ENG)  1893-1905       20    33        4  1415
#
#    Highest_inn_score    Avg BallsFaced  Strike_rate  100  50  0    4s  6s
# 8                207  58.61        NaN          0.0   15  19  6  258+   2
# 14               220  56.68        NaN          0.0   15  14  1  107+  11
# 53              144*  48.79        NaN          0.0    5   6  3   51+   0

# %%
df['BallsFaced'] = df['BallsFaced'].fillna(0)

# %%
df['Strike_rate'] = df['Strike_rate'].fillna(0)

# %%
df[df['Player']== 'CL Walcott (WI)']
# Out:
#              Player       Span  Matches  Inns  Not_Out  Runs  \
# 14  CL Walcott (WI)  1948-1960       44    74        7  3798
#
#    Highest_inn_score    Avg BallsFaced  Strike_rate  100  50  0    4s  6s
# 14               220  56.68          0          0.0   15  14  1  107+  11

# %%
df[df['Player']== 'Hon.FS Jackson (ENG)']
# Out:
#                   Player       Span  Matches  Inns  Not_Out  Runs  \
# 53  Hon.FS Jackson (ENG)  1893-1905       20    33        4  1415
#
#    Highest_inn_score    Avg BallsFaced  Strike_rate  100  50  0   4s 6s
# 53              144*  48.79          0          0.0    5   6  3  51+  0

# %%
#check duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 59    False
# 60    False
# 61    False
# 62     True
# 63     True
# Length: 64, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                    Player       Span  Matches  Inns  Not_Out   Runs  \
# 62         J  Ryder (AUS)  1920-1929       20    32        5   1394
# 63  DPMD Jayawardene (SL)  1997-2014      149   252       15  11814
#
#    Highest_inn_score    Avg BallsFaced  Strike_rate  100  50   0    4s  6s
# 62              201*  51.61      2035+        44.86    3   9   1  102+   3
# 63               374  49.84      22959        51.45   34  50  15  1387  61

# %%
df[df['Player'].isin(['DPMD Jayawardene (SL)'])]
# Out:
#                    Player       Span  Matches  Inns  Not_Out   Runs  \
# 41  DPMD Jayawardene (SL)  1997-2014      149   252       15  11814
# 63  DPMD Jayawardene (SL)  1997-2014      149   252       15  11814
#
#    Highest_inn_score    Avg BallsFaced  Strike_rate  100  50   0    4s  6s
# 41               374  49.84      22959        51.45   34  50  15  1387  61
# 63               374  49.84      22959        51.45   34  50  15  1387  61

# %%
df = df.drop_duplicates()

# %%
#splitting span to start and end date

# %%
df['Span']
# Out:
# 0     1928-1948
# 1     2022-2023
# 2     2015-2016
# 3     1963-1970
# 4     1930-1954
#         ...
# 57    2002-2014
# 58    1924-1934
# 59    1930-1938
# 60    1928-1934
# 61    1920-1929
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 57    [2002, 2014]
# 58    [1924, 1934]
# 59    [1930, 1938]
# 60    [1928, 1934]
# 61    [1920, 1929]
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Last_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Out  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80       10  6996
# 1      HC Brook (ENG)  2022-2023       12    20        1  1181
# 2      AC voges (AUS)  2015-2016       20    31        7  1485
# 3     RG Pollock (SA)  1963-1970       23    41        4  2256
# 4     GA Headley (WI)  1930-1954       22    40        4  2190
# ..                ...        ...      ...   ...      ...   ...
# 57  GC Smith (ICC/SA)  2002-2014      117   205       13  9265
# 58  WH Ponsford (AUS)  1924-1934       29    48        4  2122
# 59    SJ McCabe (AUS)  1930-1938       39    62        5  2748
# 60   DR Jardine (ENG)  1928-1934       22    33        6  1296
# 61     J  Ryder (AUS)  1920-1929       20    32        5  1394
#
#    Highest_inn_score    Avg BallsFaced  Strike_rate  100  50   0     4s  6s  \
# 0                334  99.94      9800+        58.60   29  13   7   626+   6
# ...

# %%
df = df.drop(['Span'], axis = 1)

# %%
df.head()
# Out:
#              Player  Matches  Inns  Not_Out  Runs Highest_inn_score    Avg  \
# 0  DG Bradman (AUS)       52    80       10  6996               334  99.94
# 1    HC Brook (ENG)       12    20        1  1181               186  62.15
# 2    AC voges (AUS)       20    31        7  1485              269*  61.87
# 3   RG Pollock (SA)       23    41        4  2256               274  60.97
# 4   GA Headley (WI)       22    40        4  2190              270*  60.83
#
#   BallsFaced  Strike_rate  100  50  0     4s  6s Rookie_Year Last_Year
# 0      9800+        58.60   29  13  7   626+   6        1928      1948
# 1       1287        91.76    4   7  1    141  23        2022      2023
# 2       2667        55.68    5   4  2    186   5        2015      2016
# 3      1707+        54.48    7  11  1   246+  11        1963      1970
# 4       416+        56.00   10   5  2  104 +   1        1930      1954

# %%
#create column for country

# %%
df['Player'].str.split(pat = '(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 57    [GC Smith , ICC/SA)]
# 58    [WH Ponsford , AUS)]
# 59      [SJ McCabe , AUS)]
# 60     [DR Jardine , ENG)]
# 61       [J  Ryder , AUS)]
# Name: Player, Length: 62, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['Country']
# Out:
# 0        AUS)
# 1        ENG)
# 2        AUS)
# 3         SA)
# 4         WI)
#        ...
# 57    ICC/SA)
# 58       AUS)
# 59       AUS)
# 60       ENG)
# 61       AUS)
# Name: Country, Length: 62, dtype: object

# %%
df['Country'] = df['Country'].str.split(pat = ')').str[0]

# %%
df['Country']
# Out:
# 0        AUS
# 1        ENG
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 57    ICC/SA
# 58       AUS
# 59       AUS
# 60       ENG
# 61       AUS
# Name: Country, Length: 62, dtype: object

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df
# Out:
#           Player  Matches  Inns  Not_Out  Runs Highest_inn_score    Avg  \
# 0    DG Bradman        52    80       10  6996               334  99.94
# 1      HC Brook        12    20        1  1181               186  62.15
# 2      AC voges        20    31        7  1485              269*  61.87
# 3    RG Pollock        23    41        4  2256               274  60.97
# 4    GA Headley        22    40        4  2190              270*  60.83
# ..           ...      ...   ...      ...   ...               ...    ...
# 57     GC Smith       117   205       13  9265               277  48.25
# 58  WH Ponsford        29    48        4  2122               266  48.22
# 59    SJ McCabe        39    62        5  2748               232  48.21
# 60   DR Jardine        22    33        6  1296               127  48.00
# 61     J  Ryder        20    32        5  1394              201*  51.61
#
#    BallsFaced  Strike_rate  100  50   0     4s  6s Rookie_Year Last_Year  \
# ...

# %%
#change datatypes

# %%
df.dtypes
# Out:
# Player                object
# Matches                int64
# Inns                   int64
# Not_Out                int64
# Runs                   int64
# Highest_inn_score     object
# Avg                  float64
# BallsFaced            object
# Strike_rate          float64
# 100                    int64
# 50                     int64
# 0                      int64
# 4s                    object
# 6s                    object
# Rookie_Year           object
# Last_Year             object
# Country               object
# dtype: object

# %%
df['Highest_inn_score'].str.split(pat = '*').str[0]
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 57    277
# 58    266
# 59    232
# 60    127
# 61    201
# Name: Highest_inn_score, Length: 62, dtype: object

# %%
df['Highest_inn_score']=df['Highest_inn_score'].str.split(pat = '*').str[0]

# %%
df['Highest_inn_score']
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 57    277
# 58    266
# 59    232
# 60    127
# 61    201
# Name: Highest_inn_score, Length: 62, dtype: object

# %%
df['Highest_inn_score']=df['Highest_inn_score'].astype('int')

# %%
df.dtypes
# Out:
# Player                object
# Matches                int64
# Inns                   int64
# Not_Out                int64
# Runs                   int64
# Highest_inn_score      int64
# Avg                  float64
# BallsFaced            object
# Strike_rate          float64
# 100                    int64
# 50                     int64
# 0                      int64
# 4s                    object
# 6s                    object
# Rookie_Year           object
# Last_Year             object
# Country               object
# dtype: object

# %%
df = df.astype({'Rookie_Year':'int', 'Last_Year':'int'})

# %%
df.dtypes
# Out:
# Player                object
# Matches                int64
# Inns                   int64
# Not_Out                int64
# Runs                   int64
# Highest_inn_score      int64
# Avg                  float64
# BallsFaced            object
# Strike_rate          float64
# 100                    int64
# 50                     int64
# 0                      int64
# 4s                    object
# 6s                    object
# Rookie_Year            int64
# Last_Year              int64
# Country               object
# dtype: object

# %%
df['BallsFaced'] = df['BallsFaced'].str.split(pat = '+').str[0]

# %%
df['BallsFaced']
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 4       416
#       ...
# 57    15525
# 58     3118
# 59     3217
# 60     2110
# 61     2035
# Name: BallsFaced, Length: 62, dtype: object

# %%
df.isnull().any()
# Out:
# Player               False
# Matches              False
# Inns                 False
# Not_Out              False
# Runs                 False
# Highest_inn_score    False
# Avg                  False
# BallsFaced            True
# Strike_rate          False
# 100                  False
# 50                   False
# 0                    False
# 4s                   False
# 6s                   False
# Rookie_Year          False
# Last_Year            False
# Country              False
# dtype: bool

# %%
df[df['BallsFaced'].isna()==1]
# Out:
#              Player  Matches  Inns  Not_Out  Runs  Highest_inn_score    Avg  \
# 8        ED Weekes        48    81        5  4455                207  58.61
# 14      CL Walcott        44    74        7  3798                220  56.68
# 53  Hon.FS Jackson        20    33        4  1415                144  48.79
#
#    BallsFaced  Strike_rate  100  50  0    4s  6s  Rookie_Year  Last_Year  \
# 8         NaN          0.0   15  19  6  258+   2         1948       1958
# 14        NaN          0.0   15  14  1  107+  11         1948       1960
# 53        NaN          0.0    5   6  3   51+   0         1893       1905
#
#    Country
# 8       WI
# 14      WI
# 53     ENG

# %%
df['BallsFaced'] = df['BallsFaced'].fillna(0)

# %%
df.isnull().any()
# Out:
# Player               False
# Matches              False
# Inns                 False
# Not_Out              False
# Runs                 False
# Highest_inn_score    False
# Avg                  False
# BallsFaced           False
# Strike_rate          False
# 100                  False
# 50                   False
# 0                    False
# 4s                   False
# 6s                   False
# Rookie_Year          False
# Last_Year            False
# Country              False
# dtype: bool

# %%
df['BallsFaced'] = df['BallsFaced'].astype(int)

# %%
df.dtypes
# Out:
# Player                object
# Matches                int64
# Inns                   int64
# Not_Out                int64
# Runs                   int64
# Highest_inn_score      int64
# Avg                  float64
# BallsFaced             int64
# Strike_rate          float64
# 100                    int64
# 50                     int64
# 0                      int64
# 4s                    object
# 6s                    object
# Rookie_Year            int64
# Last_Year              int64
# Country               object
# dtype: object

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                Player  Matches  Inns  Not_Out   Runs  Highest_inn_score  \
# 0         DG Bradman        52    80       10   6996                334
# 1           HC Brook        12    20        1   1181                186
# 2           AC voges        20    31        7   1485                269
# 3         RG Pollock        23    41        4   2256                274
# 4         GA Headley        22    40        4   2190                270
# 5        H Sutcliffe        54    84        9   4555                194
# 6          E Paynter        20    31        5   1540                243
# 7      KF Barrington        82   131       15   6806                256
# 8          ED Weekes        48    81        5   4455                207
# 9         WR Hammond        85   140       16   7249                336
# 10         GS Sobers        93   160       21   8032                365
# 11     KC Sangakkara       134   233       17  12400                319
# ...

# %%
#career length column

# %%
df['Career_Length'] = df['Last_Year'] - df['Rookie_Year']

# %%
df.head(5)
# Out:
#         Player  Matches  Inns  Not_Out  Runs  Highest_inn_score    Avg  \
# 0  DG Bradman        52    80       10  6996                334  99.94
# 1    HC Brook        12    20        1  1181                186  62.15
# 2    AC voges        20    31        7  1485                269  61.87
# 3  RG Pollock        23    41        4  2256                274  60.97
# 4  GA Headley        22    40        4  2190                270  60.83
#
#    BallsFaced  Strike_rate  100  50  0     4s  6s  Rookie_Year  Last_Year  \
# 0        9800        58.60   29  13  7   626+   6         1928       1948
# 1        1287        91.76    4   7  1    141  23         2022       2023
# 2        2667        55.68    5   4  2    186   5         2015       2016
# 3        1707        54.48    7  11  1   246+  11         1963       1970
# 4         416        56.00   10   5  2  104 +   1         1930       1954
#
#   Country  Career_Length
# 0     AUS             20
# 1     ENG              1
# ...

# %%
df['Career_Length'].mean()
# Out:
# 13.193548387096774

# %%
#avg strike rate for players playing over 10 years

# %%
df[df['Career_Length'] > 10]['Strike_rate'].mean()
# Out:
# 47.94681818181819

# %%
#players playing before a particular year

# %%
df[(df['Rookie_Year'] >= 1960) & (df['Rookie_Year'] < 1965)]
# Out:
#          Player  Matches  Inns  Not_Out  Runs  Highest_inn_score    Avg  \
# 3   RG Pollock        23    41        4  2256                274  60.97
# 51    KC Bland        21    39        5  1669                144  49.08
#
#     BallsFaced  Strike_rate  100  50  0    4s  6s  Rookie_Year  Last_Year  \
# 3         1707        54.48    7  11  1  246+  11         1963       1970
# 51         885        37.74    3   9  2  123+  20         1961       1966
#
#    Country  Career_Length
# 3       SA              7
# 51      SA              5

# %%
df[(df['Last_Year'] >= 2010) & (df['Last_Year'] < 2023)]
# Out:
#                Player  Matches  Inns  Not_Out   Runs  Highest_inn_score  \
# 2           AC voges        20    31        7   1485                269
# 11     KC Sangakkara       134   233       17  12400                319
# 16          JH Kalis       166   280       40  13289                224
# 23     SR -rendulkar       200   329       33  15921                248
# 26          R Dravid       164   286       32  13288                270
# 27   Mohammad Yousuf        90   156       12   7530                223
# 28       Younis Khan       118   213       19  10099                313
# 29        RT Ponting       168   287       29  13378                257
# 31        MEK Hussey        79   137       16   6235                195
# 32     S Chanderpaul       164   280       49  11867                203
# 36    AB de Villiers       114   191       18   8765                278
# 41  DPMD Jayawardene       149   252       15  11814                374
# ...

# %%
len(df[(df['Last_Year'] >= 2010) & (df['Last_Year'] < 2023)])
# Out:
# 17

# %%
df.groupby('Country')['Highest_inn_score'].max().to_frame('Highincountry').reset_index().sort_values('Highincountry', ascending=False)
# Out:
#     Country  Highincountry
# 6    ICC/WI            400
# 1       AUS            380
# 11       SL            374
# 12       WI            365
# 2       ENG            364
# 4   ICC/PAK            329
# 3   ICC/IND            319
# 9       PAK            313
# 10       SA            278
# 5    ICC/SA            277
# 7        ND            254
# 8        NZ            251
# 0        2M            232
